# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Sayantan Datta\Downloads\spotify dataset.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# ...

# %%
df["playlist_genre"].unique()
# Out:
# array(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], dtype=object)

# %%
corr_matrix=df.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True, square=True)
plt.show()

#energy and loudness are highly correlated

# %%
#energy and loudness have strong correlation
df2=df.drop(["loudness"], axis=1)
df2
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df2.columns.values
# Out:
# array(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre',
#        'playlist_subgenre', 'danceability', 'energy', 'key', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms'], dtype=object)

# %%
df['duration_ms']
# Out:
# 0        194754
# 1        162600
# 2        176616
# 3        169093
# 4        189052
#           ...
# 32828    204375
# 32829    353120
# 32830    210112
# 32831    367432
# 32832    337500
# Name: duration_ms, Length: 32833, dtype: int64

# %%
df_audio=df2.drop(['mode','track_id','track_name','track_artist','track_popularity','track_album_id','track_album_name','track_album_release_date','playlist_name','playlist_id','playlist_genre','playlist_subgenre','duration_ms'], axis=1)

# %%
df_audio
# Out:
#        danceability  energy  key  speechiness  acousticness  instrumentalness  \
# 0             0.748   0.916    6       0.0583      0.102000          0.000000
# 1             0.726   0.815   11       0.0373      0.072400          0.004210
# 2             0.675   0.931    1       0.0742      0.079400          0.000023
# 3             0.718   0.930    7       0.1020      0.028700          0.000009
# 4             0.650   0.833    1       0.0359      0.080300          0.000000
# ...             ...     ...  ...          ...           ...               ...
# 32828         0.428   0.922    2       0.0936      0.076600          0.000000
# 32829         0.522   0.786    0       0.0420      0.001710          0.004270
# 32830         0.529   0.821    6       0.0481      0.108000          0.000001
# 32831         0.626   0.888    2       0.1090      0.007920          0.127000
# 32832         0.603   0.884    5       0.0385      0.000133          0.341000
#
# ...

# %%
df[df_audio.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_artist, track_popularity, track_album_id, track_album_name, track_album_release_date, playlist_name, playlist_id, playlist_genre, playlist_subgenre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms]
# Index: []
#
# [0 rows x 23 columns]

# %%
corr_matrix=df_audio.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True, square=True)
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples

# %%
Sum_of_squared_distances = []
K = range(1,10)
for num_clusters in K :
 kmeans = KMeans(n_clusters=num_clusters)
 kmeans.fit(df_audio)
 Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Sum of squared distances') 
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
K1 = range(2,10)
for num_clusters in K1 :
 kmeans = KMeans(n_clusters=num_clusters)
 kmeans.fit(df_audio)
 score = silhouette_score(df_audio, kmeans.labels_, metric='euclidean')
 print({'clusters': num_clusters,
        'score':score})
# Out:
# {'clusters': 2, 'score': 0.5287052784796048}
# {'clusters': 3, 'score': 0.5824942702670951}
# {'clusters': 4, 'score': 0.5384206676618281}
# {'clusters': 5, 'score': 0.4947015302414487}
# {'clusters': 6, 'score': 0.470262818228794}
# {'clusters': 7, 'score': 0.4528817160044374}
# {'clusters': 8, 'score': 0.44352994049789346}
# {'clusters': 9, 'score': 0.40948164180622854}

# %%
#optimal no. of clusters=3
km=KMeans(n_clusters=3)
km.fit(df_audio)
# Out:
# KMeans(n_clusters=3)

# %%
df_audio["cluster_group"]=km.labels_
df_audio
# Out:
#        danceability  energy  key  speechiness  acousticness  instrumentalness  \
# 0             0.748   0.916    6       0.0583      0.102000          0.000000
# 1             0.726   0.815   11       0.0373      0.072400          0.004210
# 2             0.675   0.931    1       0.0742      0.079400          0.000023
# 3             0.718   0.930    7       0.1020      0.028700          0.000009
# 4             0.650   0.833    1       0.0359      0.080300          0.000000
# ...             ...     ...  ...          ...           ...               ...
# 32828         0.428   0.922    2       0.0936      0.076600          0.000000
# 32829         0.522   0.786    0       0.0420      0.001710          0.004270
# 32830         0.529   0.821    6       0.0481      0.108000          0.000001
# 32831         0.626   0.888    2       0.1090      0.007920          0.127000
# 32832         0.603   0.884    5       0.0385      0.000133          0.341000
#
# ...
